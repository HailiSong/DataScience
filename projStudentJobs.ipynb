# %% [markdown]
# # Job Out Comes of Students Graduated from College between 2010-2012

# %% [markdown]
# The aim of this project is to visualize data.
#
# The original data on job outcomes was released by [American Community Survey](https://www.census.gov/programs-surveys/acs/), which conducts surveys and aggregates the data. FiveThirtyEight cleaned the dataset and released it on their [Github repo](https://github.com/fivethirtyeight/data/tree/master/college-majors).

# %% [markdown]
# Some of the columns in the dataset:
# * <font color="pink">Rank</font> - Rank by median earnings (the dataset is ordered by this column).
# * Major_code - Major code.
# * Major - Major description.
# * Major_category - Category of major.
# * Total - Total number of people with major.
# * Sample_size - Sample size (unweighted) of full-time.
# * Men - Male graduates.
# * Women - Female graduates.
# * ShareWomen - Women as share of total.
# * Employed - Number employed.
# * Median - Median salary of full-time, year-round workers.
# * Low_wage_jobs - Number in low-wage service jobs.
# * Full_time - Number employed 35 hours or more.
# * Part_time - Number employed less than 35 hours.

# %%
# Run the magic so that plots are displayed inline.
# %matplotlib inline

# %%
import pandas as pd

# %%
# Read file into pandas
recent_grads = pd.read_csv("recent-grads.csv")

# %%
# Show the first row formatted as a table
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
# Show how data is structured
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
# Show how data is structured by looking at tail
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
# Generate summary statistics for all of the numeric columns
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
recent_grads.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
# Look up the number of rows
raw_data_count = recent_grads.count()

# %%
raw_data_count
# Out:
# Rank                    173
# Major_code              173
# Major                   173
# Total                   172
# Men                     172
# Women                   172
# Major_category          173
# ShareWomen              172
# Sample_size             173
# Employed                173
# Full_time               173
# Part_time               173
# Full_time_year_round    173
# Unemployed              173
# Unemployment_rate       173
# Median                  173
# P25th                   173
# P75th                   173
# College_jobs            173
# Non_college_jobs        173
# Low_wage_jobs           173
# dtype: int64

# %%
# Drop rows containing missing values
recent_grads = recent_grads.dropna()

# %%
# Look up the number of rows after cleaning
cleaned_data_count = recent_grads.count()

# %%
cleaned_data_count
# Out:
# Rank                    172
# Major_code              172
# Major                   172
# Total                   172
# Men                     172
# Women                   172
# Major_category          172
# ShareWomen              172
# Sample_size             172
# Employed                172
# Full_time               172
# Part_time               172
# Full_time_year_round    172
# Unemployed              172
# Unemployment_rate       172
# Median                  172
# P25th                   172
# P75th                   172
# College_jobs            172
# Non_college_jobs        172
# Low_wage_jobs           172
# dtype: int64

# %% [markdown]
# We see that only one row contained missing values and was dropped.

# %%
# Generate scatter plots to explore relations between Sample_size and Median
recent_grads.plot(x="Sample_size", y="Median", kind="scatter", title='Median vs. Sample_size')

# %%
# Generate scatter plots to explore relations between Sample_size and Unemployment_rate
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="scatter", title="Unemployment_rate vs Sample_size")

# %%
# Generate scatter plots to explore relations between Full_time and Median
recent_grads.plot(x="Full_time", y="Median", kind="scatter", title="Median vs Full_time")

# %%
# Generate scatter plots to explore relations between ShareWomen and Unemployment_rate
recent_grads.plot(x="ShareWomen", y="Unemployment_rate", kind="scatter", title="Unemployment_rate vs ShareWomen")

# %%
# Generate scatter plots to explore relations between Men and Median
recent_grads.plot(x="Men", y="Median", kind="scatter", title="Median vs Men")

# %%
# Generate scatter plots to explore relations between Women and Median
recent_grads.plot(x="Women", y="Median", kind="scatter", title="Meidan vs Women")

# %% [markdown]
# Questions:
# * Do students in more popular majors make more money?
# * Do students that majored in subjects that were majority female make more money?
# * Is there any link between the number of full-time employees and median salary?

# %% [markdown]
# Answer:
# * From the scatter plot _Unemployment_rate vs ShareWomen_, we're not seeing students in more popular majors make more money. There is no clear relation between these two items.
# * There is no clear relation between subjects that were majority female and salary (see scatter plot Meidan vs Women)
# * There is not link between the number of full-time employees and the median salary.

# %% [markdown]
# ### Distribution of values in a column
# Generate histograms in separate jupyter notebook cells to explore the distributions of the following columns:

# %%
recent_grads['Sample_size'].hist(bins=25, range=(1,5000))

# %%
recent_grads['Median'].hist(bins=25)

# %%
recent_grads['Employed'].hist(bins=25, range=(0,50000))

# %%
recent_grads['Full_time'].hist(bins=25,range=(0,100000))

# %%
recent_grads['ShareWomen'].hist(bins=25)

# %%
recent_grads['Unemployment_rate'].hist(bins=25)

# %%
recent_grads['Men'].hist(bins=25,range=(0,5000))

# %%
recent_grads['Women'].hist(bins=25, range=(0,8000))

# %% [markdown]
# Question:
# * What percent of majors are predominantly male? Predominantly female?
# * What's the most common median salary range?

# %% [markdown]
# Answer:
# * 60% of majors are predominatly male, and 40% are female, as estimated based on the ShareWomen histogram.
# * The most common median salary range is 2000~5000.

# %% [markdown]
# ### Pandas, Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[["Sample_size", "Median"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1200d1290>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size", "Median", "Unemployment_rate"]], figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x120569c50>,
# ...
#       dtype=object)

# %% [markdown]
# ### Pandas, bar plots

# %%
# first 10 rows of ShareWomen 
recent_grads[:10].plot.bar(x='Major', y="ShareWomen")

# %%
# last 10 rows of "ShareWomen"
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen')

# %%
# First 10 rows of the Unemployment_rate
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

# %%
# First 10 rows of the Unemployment_rate
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate')

# %% [markdown]
# ### Grouped bar plot

# %%
man_women = recent_grads[["Major_category", "Men","Women"]]

# %%
man_women.head()
# Out:
#   Major_category      Men    Women
# 0    Engineering   2057.0    282.0
# 1    Engineering    679.0     77.0
# 2    Engineering    725.0    131.0
# 3    Engineering   1123.0    135.0
# 4    Engineering  21239.0  11021.0

# %%
df.set_index('Word').plot(kind='bar')
df.plot(x="Word", y=["Percentage1", "Percentage2"], kind="bar")

# %%
recent_grads.groupby('Major_category')[['Men', 'Women']].sum()
# Out:
#                                           Men     Women
# Major_category
# Agriculture & Natural Resources       40357.0   35263.0
# Arts                                 134390.0  222740.0
# Biology & Life Science               184919.0  268943.0
# Business                             667852.0  634524.0
# Communications & Journalism          131921.0  260680.0
# Computers & Mathematics              208725.0   90283.0
# Education                            103526.0  455603.0
# Engineering                          408307.0  129276.0
# Health                                75517.0  387713.0
# Humanities & Liberal Arts            272846.0  440622.0
# Industrial Arts & Consumer Services  103781.0  126011.0
# Interdisciplinary                      2817.0    9479.0
# Law & Public Policy                   91129.0   87978.0
# Physical Sciences                     95390.0   90089.0
# Psychology & Social Work              98115.0  382892.0
# ...

# %%
recent_grads.groupby('Major_category')[['Men', 'Women']].sum().plot.bar()

# %% [markdown]
# ### Box plot to explore distribution of some columns

# %%
# Median salary
recent_grads[['Median']].boxplot()

# %%
# Unemployment rate
recent_grads[['Unemployment_rate']].boxplot()

# %% [markdown]
# ### Hexagonal bin plot

# %% [markdown]
# Use a hexagonal bin plot to visualize the columns that had dense scatter plots from earlier in the project.

# %%
recent_grads.plot.hexbin(x='Unemployment_rate', y='ShareWomen', gridsize=25)
